# %%
import lasio
from os import path
import numpy as np
import matplotlib.pylab as plt
from os import path
import glob

# %%
FOLDERLOC = '~/logdat/olga'
FOLDER = 'WOS'
DATAPATH = FOLDER

# %%
counter = 0
for file in glob.glob(path.join(DATAPATH, '*.las'), recursive=True):
    counter += 1
    print(counter, '\t-\t', file.replace(DATAPATH+'\\', ''))
# Out:
# 1 	-	 WOS/204_23-1_DATACO_JWDL_QC.las
# 2 	-	 WOS/205_20-2_DATACO_JWDL_QC.las
# 3 	-	 WOS/213_25c-1V_DATACO_JWDL_QC.las
# 4 	-	 WOS/214_26-1_DATACO_JWDL_QC.las
# 5 	-	 WOS/204_25a-3_DATACO_JWDL_QC.las
# 6 	-	 WOS/204_17-1_DATACO_JWDL_QC.las
# 7 	-	 WOS/204_10-2_DATACO_JWDL_QC.las
# 8 	-	 WOS/204_19-8_DATACO_JWDL_QC.las
# 9 	-	 WOS/204_27a-1_DATACO_JWDL_QC.las
# 10 	-	 WOS/206_16-1_DATACO_JWDL_QC.las
# 11 	-	 WOS/204_26-1A_DATACO_JWDL_QC.las
# 12 	-	 WOS/204_22-1_DATACO_JWDL_QC.las
# 13 	-	 WOS/206_04-2_DATACO_JWDL_QC.las
# 14 	-	 WOS/202_03-1A_DATACO_JWDL_QC.las
# 15 	-	 WOS/205_14-1_DATACO_JWDL_QC.las
# 16 	-	 WOS/204_16-1_DATACO_JWDL_QC.las
# 17 	-	 WOS/205_27-2_DATACO_JWDL_QC.las
# 18 	-	 WOS/214_27-1_DATACO_JWDL_QC.las
# 19 	-	 WOS/208_21-1_DATACO_JWDL_QC.las
# 20 	-	 WOS/205_01-1_DATACO_JWDL_QC.las
# 21 	-	 WOS/202_09-1_DATACO_JWDL_QC.las
# 22 	-	 WOS/205_10-5A_DATACO_JWDL_QC.las
# 23 	-	 WOS/207_01-2_DATACO_JWDL_QC.las
# 24 	-	 WOS/204_13-1_DATACO_JWDLC_QC.las
# 25 	-	 WOS/205_23-2_DATACO_JWDL_QC.las
# 26 	-	 WOS/205_26-1_DATACO_JWDL_QC.las
# 27 	-	 WOS/206_01-2_DATACO_JWDL_QC.las
# 28 	-	 WOS/207_01-1_DATACO_JWDL_QC.las
# 29 	-	 WOS/205_10-4_DATACO_JWDL_QC.las
# 30 	-	 WOS/204_29a-2_DATACO_JWDL_QC.las
# 31 	-	 WOS/206_01-1A_DATACO_JWDL_QC.las
# 32 	-	 WOS/204_15-1_DATACO_JWDL_QC.las
# 33 	-	 WOS/206_12-2_DATACO_JWDL_QC.las
# 34 	-	 WOS/204_19-7_DATACO_JWDL_QC.las
# 35 	-	 WOS/208_11-1_DATACO_JWDL_QC.las
# 36 	-	 WOS/214_28-1_DATACO_JWDL_QC.las
# 37 	-	 WOS/206_08-4_DATACO_JWDL_QC.las
# 38 	-	 WOS/213_23-1_DATACO_JWDL_QC.las
# 39 	-	 WOS/207_02-1_DATACO_JWDL_QC.las
# 40 	-	 WOS/204_21-1_DATACO_JWDL_QC.las
# 41 	-	 WOS/206_08-2_DATACO_JWDL_QC.las
# 42 	-	 WOS/206_08-11A_DATACO_JWDL_QC.las
# 43 	-	 WOS/206_12a-3_DATACO_JWDL_QC.las
# 44 	-	 WOS/207_01a-5_DATACO_JWDL_QC.las
# 45 	-	 WOS/206_05a-3_DATACO_JWDL_QC.las
# 46 	-	 WOS/206_01a-4Z_DATACO_JWDL_QC.las
# 47 	-	 WOS/202_18-1_DATACO_JWDL_QC.las
# 48 	-	 WOS/204_24a-7_DATACO_JWDL_QC.las
# 49 	-	 WOS/209_03-1A_DATACO_JWDL_QC.las
# 50 	-	 WOS/204_20-3_DATACO_JWDL_QC.las
# 51 	-	 WOS/204_28-2_DATACO_JWDL_QC.las
# 52 	-	 WOS/204_24-1A_DATACO_JWDL_QC.las
# 53 	-	 WOS/205_09-1_DATACO_JWDL_QC.las
# 54 	-	 WOS/204_19-9_DATACO_JWDL_QC.las
# 55 	-	 WOS/202_12-1_DATACO_JWDL_QC.las
# 56 	-	 WOS/202_04-1_DATACO_JWDL_QC.las
# 57 	-	 WOS/206_07-1_DATACO_JWDL_QC.las
# 58 	-	 WOS/207_01a-4Z_DATACO_JWDL_QC.las
# 59 	-	 WOS/206_08-7A_DATACO_JWDL_QC.las
# 60 	-	 WOS/208_24-1A_DATACO_JWDL_QC.las
# 61 	-	 WOS/207_01a-4_DATCO_JWDL_QC.las
# 62 	-	 WOS/206_08-7_DATACO_JWDL_QC.las
# 63 	-	 WOS/214_29-1_DATACO_JWDL_QC.las
# 64 	-	 WOS/205_08-1_DATACO_JWDL_QC.las
# 65 	-	 WOS/205_21-1A_DATACO_JWDL_QC.las
# 66 	-	 WOS/205_21b-3_DATACO_JWDL_QC.las
# 67 	-	 WOS/204_24a-3_DATACO_JWDL_QC.las
# 68 	-	 WOS/213_27-2_DATACO_JWDL_QC.las
# 69 	-	 WOS/217_15-1Z_DATACO_JWDL_QC.las
# 70 	-	 WOS/204_29-1_DATACO_JWDL_QC.las
# 71 	-	 WOS/214_04-1_DATACO_JWDL_QC.las
# 72 	-	 WOS/208_22-1_DATACO_JWDL_QC.las
# 73 	-	 WOS/204_25a-2_DATACO_JWDL_QC.las
# 74 	-	 WOS/202_03-2_DATACO_JWDL_QC.las
# 75 	-	 WOS/213_27-4Z_DATACO_JWDL_QC.las
# 76 	-	 WOS/209_06-1_DATACO_JWDL_QC.las
# 77 	-	 WOS/206_02-1A_DATACO_JWDL_QC.las
# 78 	-	 WOS/206_08-6A_DATACO_JWDL_QC.las
# 79 	-	 WOS/206_09-2_DATACO_JWDL_QC.las
# 80 	-	 WOS/214_09-1_DATACO_JWDL_QC.las
# 81 	-	 WOS/204_25b-4_DATACO_JWDL_QC.las
# 82 	-	 WOS/206_08-10Z_DATACO_JWDL_QC.las
# 83 	-	 WOS/206_08-9Z_DATACO_JWDL_QC.las
# 84 	-	 WOS/206_11-1_DATACO_JWDL_QC.las
# 85 	-	 WOS/205_12-1_DATACO_JWDL_QC.las
# 86 	-	 WOS/204_24a-6_DATACO_JWDL_QC.las
# 87 	-	 WOS/213_26-1_DATACO_JWDL_QC.las
# 88 	-	 WOS/204_25b-6_DATACO_JWDL_QC.las
# 89 	-	 WOS/205_17a-1_DATACO_JWDL_QC.las
# 90 	-	 WOS/204_19-6_DATACO_JWDL_QC.las
# 91 	-	 WOS/206_08-12A_DATACO_JWDL_QC.las
# 92 	-	 WOS/217_15-1_DATACO_JWDL_QC.las
# 93 	-	 WOS/202_08-1_DATACO_JWDL_QC.las
# 94 	-	 WOS/204_24a-2_DATACO_JWDL_QC.las
# 95 	-	 WOS/202_19-1_DATACO_JWDL_QC.las
# 96 	-	 WOS/208_23-1_DATACO_JWDL_QC.las
# 97 	-	 WOS/205_21-2_DATACO_JWDL_QC.las
# 98 	-	 WOS/204_14-2_DATACO_JWDL_QC.las
# 99 	-	 WOS/204_19-8Z_DATACO_JWDL_QC.las
# 100 	-	 WOS/204_28-1_DATACO_JWDL_QC.las
# 101 	-	 WOS/214_27-2_DATACO_JWDL_QC.las
# 102 	-	 WOS/205_10-3_DATACO_JWDL_QC.las
# 103 	-	 WOS/206_08-13Z_DATACO_JWDL_QC.las
# 104 	-	 WOS/205_27a-1_DATACO_JWDL_QC.las
# 105 	-	 WOS/208_27-1_DATACO_JWDL_QC.las
# 106 	-	 WOS/206_08-14_DATACO_JWDL_QC.las
# 107 	-	 WOS/213_28-1_DATACO_JWDL_QC.las
# 108 	-	 WOS/205_14-3_DATACO_JWDL_QC.las
# 109 	-	 WOS/204_22-2_DATACO_JWDL_QC.las
# 110 	-	 WOS/204_19-1_DATACO_JWDL_QC.las
# 111 	-	 WOS/208_17-3_DATACO_JWDL_QC.las
# 112 	-	 WOS/206_05-2_DATACO_JWDL_QC.las
# 113 	-	 WOS/213_27-1Z_DATACO_JWDL_QC.las
# 114 	-	 WOS/205_23-1_DATACO_JWDL_QC.las
# 115 	-	 WOS/204_20-2_DATACO_JWDL_QC.las
# 116 	-	 WOS/205_17b-2_DATACO_JWDL_QC.las
# 117 	-	 WOS/204_05a-1_DATACO_JWDL_QC.las
# 118 	-	 WOS/205_30-1_DATACO_JWDL_QC.las
# 119 	-	 WOS/204_10a-3_DATACO_JWDL_QC.las
# 120 	-	 WOS/205_22-1A_DATACO_JWDL_QC.las
# 121 	-	 WOS/204_19-5_DATACO_JWDL_QC.las
# 122 	-	 WOS/204_15-2_DATACO_JWDL_QC.las
# 123 	-	 WOS/206_08-1A_DATACO_JWDL_QC.las
# 124 	-	 WOS/206_03-1_DATACO_JWDL_QC.las
# 125 	-	 WOS/204_20-4_DATACO_JWDL_QC.las
# 126 	-	 WOS/205_09-2_DATACO_JWDL_QC.las
# 127 	-	 WOS/214_30a-2_DATACO_JWDL_QC.las
# 128 	-	 WOS/204_14-1_DATACO_JWDL_QC.las
# 129 	-	 WOS/204_20-5_DATACO_JWDL_QC.las
# 130 	-	 WOS/204_24a-5_DATACO_JWDL_QC.las
# 131 	-	 WOS/204_10-1_DATACO_JWDL_QC.las
# 132 	-	 WOS/204_18-1_DATACO_JWDL_QC.las
# 133 	-	 WOS/206_08-11Z_DATACO_JWDL_QC.las
# 134 	-	 WOS/206_13-1_DATACO_JWDL_QC.las
# 135 	-	 WOS/208_15-1A_DATACO_JWDL_QC.las
# 136 	-	 WOS/208_26-1_DATACO_JWDL_QC.las
# 137 	-	 WOS/207_01-3_DATCO_JWDL_QC.las
# 138 	-	 WOS/206_01-3_DATACO_JWDL_QC.las
# 139 	-	 WOS/208_17-2_DATACO_JWDL_QC.las
# 140 	-	 WOS/206_08-3A_DATACO_JWDL_QC.las
# 141 	-	 WOS/206_08-10_DATACO_JWDL_QC.las
# 142 	-	 WOS/208_19-1_DATACO_JWDL_QC.las
# 143 	-	 WOS/209_12-1_DATACO_JWDL_QC.las
# 144 	-	 WOS/206_08-5_DATACO_JWDL_QC.las
# 145 	-	 WOS/209_09-1_DATACO_JWDL_QC.las
# 146 	-	 WOS/202_03a-3_DATACO_JWDL_QC.las
# 147 	-	 WOS/206_13a-2A_DATACO_JWDL_QC.las
# 148 	-	 WOS/214_27a-4_DATACO_JWDL_QC.las
# 149 	-	 WOS/206_07a-2_DATACO_JWDL_QC.las
# 150 	-	 WOS/214_30-1_DATACO_JWDL_QC.las
# 151 	-	 WOS/204_25b-5_DATACO_JWDL_QC.las
# 152 	-	 WOS/208_15-2_DATACO_JWDL_QC.las
# 153 	-	 WOS/214_17-1_DATACO_JWDL_QC.las
# 154 	-	 WOS/214_24-1_DATACO_JWDL_QC.las
# 155 	-	 WOS/204_20-1_DATACO_JWDL_QC.las
# 156 	-	 WOS/205_10-2B_DATACO_JWDL_QC.las
# 157 	-	 WOS/205_05a-1_DATACO_JWDL_QC.las
# 158 	-	 WOS/204_24a-2Y_DATACO_JWDL_QC.las
# 159 	-	 WOS/204_19-4A_DATACO_JWDL_QC.las
# 160 	-	 WOS/205_16-1_DATACO_JWDL_QC.las
# 161 	-	 WOS/213_27-4_DATACO_JWDL_QC.las
# 162 	-	 WOS/204_19-3A_DATACO_JWDL_QC.las
# 163 	-	 WOS/204_23-2_DATACO_JWDL_QC.las
# 164 	-	 WOS/206_08-9Y_DATACO_JWDL_QC.las
# 165 	-	 WOS/205_14-2_DATACO_JWDL_QC.las
# 166 	-	 WOS/204_20-1Z_DATACO_JWDL_QC.las
# 167 	-	 WOS/204_20a-7_DATACO_JWDL_QC.las
# 168 	-	 WOS/204_10a-4_DATACO_JWDL_QC.las
# 169 	-	 WOS/204_30-1_DATACO_JWDL_QC.las
# 170 	-	 WOS/206_04-1_DATACO_JWDL_QC.las
# 171 	-	 WOS/205_16-2_DATACO_JWDL_QC.las
# 172 	-	 WOS/213_27-3Z_DATACO_JWDL_QC.las
# 173 	-	 WOS/204_19-2_DATACO_JWDL_QC.las
# 174 	-	 WOS/206_08-8_DATACO_JWDL_QC.las
# 175 	-	 WOS/214_27a-3_DATACO_JWDL_QC.las
# 176 	-	 WOS/205_26a-2_DATACO_JWDL_QC.las
# 177 	-	 WOS/209_04-1A_DATACO_JWDL_QC.las
# 178 	-	 WOS/208_17-1_DATACO_JWDL_QC.las
# 179 	-	 WOS/205_25-1_DATACO_JWDL_QC.las
# 180 	-	 WOS/204_20-6A_DATACO_JWDL_QC.las
# 181 	-	 WOS/214_19-1_DATACO_JWDL_QC.las
# 182 	-	 WOS/202_02-1_DATACO_JWDL_QC.las
# 183 	-	 WOS/204_25-1_DATACO_JWDL_QC.las
# 184 	-	 WOS/205_20-1_DATACO_JWDL_QC.las
# 185 	-	 WOS/206_08-15_DATACO_JWDL_QC.las
# 186 	-	 WOS/204_24a-2Z_DATACO_JWDL_QC.las

# %%
print(counter)
# Out:
# 186

# %%
# extract the data
las_names = []
curves = []
for file in glob.glob(path.join(DATAPATH, '*.las')):
    las_name = file.replace(DATAPATH + '\\', '') 
    las_names.append(las_name)
    las = lasio.read(las_name)
    data = las.df()
    curves.append(list(data.columns))

file_curves = dict(zip(las_names, curves))
    
# print the lists
for l in range(len(las_names)):
    print(las_names[l], ' ', curves[l])
# Out:
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# WOS/204_23-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/205_20-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_25c-1V_DATACO_JWDL_QC.las   ['AE20', 'AE60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RMED', 'RPCHM', 'RPCLM', 'RSHAL']
# WOS/214_26-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RAC', 'RDEP', 'RPC', 'RSHAL']
# WOS/204_25a-3_DATACO_JWDL_QC.las   ['AO10', 'AO20', 'AO30', 'AO60', 'AO90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_17-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RSHAL', 'RXO', 'SP']
# WOS/204_10-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'R25P', 'R55P', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-8_DATACO_JWDL_QC.las   ['CALI', 'DTC', 'GR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_27a-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_16-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACM', 'RDEP', 'RMIC', 'RPCM', 'RSHAL']
# WOS/204_26-1A_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'IDPH', 'IMPH', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/204_22-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL']
# WOS/206_04-2_DATACO_JWDL_QC.las   ['A16H', 'A16L', 'A22H', 'A22L', 'A28H', 'A28L', 'A34H', 'A34L', 'A40H', 'A40L', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'GR_LWD', 'M2R1', 'M2R2', 'M2R3', 'M2R6', 'M2R9', 'M2RX', 'NEUT', 'P16H', 'P16L', 'P22H', 'P22L', 'P28H', 'P28L', 'P34H', 'P34L', 'P40H', 'P40L', 'PEF', 'RDEP', 'RES_BM', 'RES_BS', 'RES_RING', 'RMIC', 'RSHAL', 'SFR10C', 'SFR12C', 'SFR14C', 'SFR16C', 'SFR20C', 'SFR30C', 'SFR40C', 'SFR50C', 'SP']
# WOS/202_03-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_14-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'IDPH', 'IMPH', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SFLU']
# WOS/204_16-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RMLL', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50']
# WOS/205_27-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/214_27-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SP']
# WOS/208_21-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RMIC', 'RSHAL']
# WOS/205_01-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTSM', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS', 'RES_RING', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXO']
# WOS/202_09-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_10-5A_DATACO_JWDL_QC.las   ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/207_01-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_13-1_DATACO_JWDLC_QC.las   ['CALI', 'DENC', 'DENC_LWD', 'DENS', 'DENS_LWD', 'DTC', 'DTS', 'GR', 'NEUT', 'NEUT_LWD', 'PEF', 'RDEP', 'RDEP_LWD', 'RMED', 'RMED_LWD', 'RMIC', 'RMIC_LWD', 'RSHAL', 'RSHAL_LWD']
# WOS/205_23-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/205_26-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_01-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'SP']
# WOS/207_01-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/205_10-4_DATACO_JWDL_QC.las   ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/204_29a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_01-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_15-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'GR_LWD', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_12-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/204_19-7_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/208_11-1_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RXOZ', 'SP']
# WOS/214_28-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/206_08-4_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_23-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/207_02-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_21-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-11A_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/206_12a-3_DATACO_JWDL_QC.las   ['AE10', 'AE20', 'AE30', 'AE60', 'AE90', 'BDCM', 'CALI', 'DENC', 'DENS', 'DTC', 'DTPM', 'DTS', 'GR', 'NEUT', 'NPLM', 'PEF', 'RACHM', 'RACLM', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RT_HRLT', 'RXO8', 'SP']
# WOS/207_01a-5_DATACO_JWDL_QC.las   ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'SP']
# WOS/206_05a-3_DATACO_JWDL_QC.las   ['DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXOZ', 'SP']
# WOS/206_01a-4Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'MLL', 'NEUT', 'PEF', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50', 'SP']
# WOS/202_18-1_DATACO_JWDL_QC.las   ['CALI', 'DTC', 'GR', 'ILD', 'ILM', 'RD', 'RDEP', 'RFOC', 'RMIC', 'RS']
# WOS/204_24a-7_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS_1', 'DTS_2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/209_03-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/204_20-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_28-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'HDRA', 'NEUT', 'PEF', 'RDEP', 'RHOZ', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXOZ', 'SBD2', 'SCO2', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SPLF', 'TNPH']
# WOS/204_24-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_09-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'LL3', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-9_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SEMP']
# WOS/202_12-1_DATACO_JWDL_QC.las   ['ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/202_04-1_DATACO_JWDL_QC.las   ['AT60', 'ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_07-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/207_01a-4Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'SP']
# WOS/206_08-7A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/208_24-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'SP']
# WOS/207_01a-4_DATCO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-7_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/214_29-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/205_08-1_DATACO_JWDL_QC.las   ['AHO10', 'AHO20', 'AHO30', 'AHO60', 'AHO90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'SEDP', 'SEMP', 'SESP', 'SEWP', 'SEXP', 'SP']
# WOS/205_21-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'I5FR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'SFL', 'SP']
# WOS/205_21b-3_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS_1', 'DTS_2', 'GR', 'NEUT', 'PEF']
# WOS/204_24a-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/213_27-2_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT']
# WOS/217_15-1Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RT_HRLT', 'RXOZ']
# WOS/204_29-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SP']
# WOS/214_04-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SP']
# WOS/208_22-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_25a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/202_03-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/213_27-4Z_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS']
# WOS/209_06-1_DATACO_JWDL_QC.las   ['CALI', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_02-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_08-6A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_09-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/214_09-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RACL', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCH', 'RPCL', 'RXOZ', 'SP']
# WOS/204_25b-4_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-10Z_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'ATRT', 'ATRX', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/206_08-9Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'SEWR']
# WOS/206_11-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MLL', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/205_12-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/204_24a-6_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/213_26-1_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT', 'SP']
# WOS/204_25b-6_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DT5', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SEMP']
# WOS/205_17a-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_19-6_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-12A_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/217_15-1_DATACO_JWDL_QC.las   ['BDCM', 'CALCM', 'CALI', 'DENC', 'DENS', 'DPEM', 'DRHM', 'DTC', 'DTPM', 'DTSH3', 'DTSH5', 'DTSH6', 'DTSM', 'GRCM', 'NPLM', 'PEF', 'RACHM', 'RACLM', 'RPCHM', 'RPCLM']
# WOS/202_08-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_24a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/202_19-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SFLU', 'SP']
# WOS/208_23-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_21-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_14-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RACL', 'RACM', 'RDEP', 'RMIC', 'RPCH', 'RPCL', 'RPCM', 'RSHAL', 'SP']
# WOS/204_19-8Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_28-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/214_27-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/205_10-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/206_08-13Z_DATACO_JWDL_QC.las   ['AF10', 'AF20', 'AF30', 'AF60', 'AF90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/205_27a-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RSHAL', 'SP']
# WOS/208_27-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-14_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/213_28-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'GR_LWD', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RPCHM', 'RPCLM']
# WOS/205_14-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_22-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL']
# WOS/208_17-3_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RXO', 'SP']
# WOS/206_05-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_27-1Z_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DEPTH_M', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RMIC', 'RSHAL', 'RXOZ', 'SP']
# WOS/205_23-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'RDEP', 'RSHAL', 'SP']
# WOS/204_20-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_17b-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_05a-1_DATACO_JWDL_QC.las   ['CALI_LWD', 'CALI_WL', 'DENC', 'DENS', 'DTC', 'DTS', 'GR_LWD', 'GR_WL', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RT_HRLT', 'RXO_HRLT']
# WOS/205_30-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_10a-3_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/205_22-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-5_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_15-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RD', 'RMLL', 'RS', 'SP']
# WOS/206_08-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_03-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/204_20-4_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_09-2_DATACO_JWDL_QC.las   ['A28H', 'CALI', 'DENC', 'DENS', 'DTC', 'DXDT', 'DYDT', 'GR', 'LLD', 'LLS', 'MSFL', 'NEUT', 'P28H', 'PEF', 'RT10', 'RT20', 'RT30', 'RT60', 'RT90', 'SP']
# WOS/214_30a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RXOZ', 'SP']
# WOS/204_14-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_20-5_DATACO_JWDL_QC.las   ['DENC', 'DENS', 'GR', 'NEUT', 'RDEP', 'RMED', 'RMIC', 'RSHAL']
# WOS/204_24a-5_DATACO_JWDL_QC.las   ['AIT_10', 'AIT_20', 'AIT_30', 'AIT_60', 'AIT_90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/204_10-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SF10', 'SF12', 'SF14', 'SF16', 'SF20', 'SF30', 'SF40', 'SF50']
# WOS/204_18-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTX2', 'GR', 'NEUT', 'PEF', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50', 'SPLF']
# WOS/206_08-11Z_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'ATRT', 'ATRX', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/206_13-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/208_15-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/208_26-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/207_01-3_DATCO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SFLU', 'SP']
# WOS/206_01-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'M0R1', 'M0R2', 'M0R3', 'M0R6', 'M0R9', 'NEUT', 'PEF', 'RDEP', 'RIPD', 'RIPM', 'RMED', 'RSFL', 'RSHAL', 'SP']
# WOS/208_17-2_DATACO_JWDL_QC.las   ['AF30', 'AF90', 'AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT']
# WOS/206_08-3A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-10_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'PEF']
# WOS/208_19-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/209_12-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/206_08-5_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/209_09-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/202_03a-3_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL']
# WOS/206_13a-2A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'NEUT', 'PEF', 'RD', 'RS', 'SP']
# WOS/214_27a-4_DATACO_JWDL_QC.las   ['ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_07a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/214_30-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_25b-5_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF']
# WOS/208_15-2_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'ILD', 'ILM', 'LLD', 'LLS', 'NEUT', 'RMIC', 'SFLU', 'SP']
# WOS/214_17-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'SP']
# WOS/214_24-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SP']
# WOS/204_20-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_10-2B_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/205_05a-1_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_RING', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXOZ']
# WOS/204_24a-2Y_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP']
# WOS/204_19-4A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_16-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/213_27-4_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'SP']
# WOS/204_19-3A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'RT', 'SP']
# WOS/204_23-2_DATACO_JWDL_QC.las   ['AHT20', 'AHT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RMED', 'RPCHM', 'RPCLM', 'RSHAL']
# WOS/206_08-9Y_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DT4P', 'DT4S', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/205_14-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'M2R1', 'M2R2', 'M2R3', 'M2R6', 'M2R9', 'M2RX', 'NEUT', 'PEF', 'RDC', 'RMLL', 'RSC', 'SP']
# WOS/204_20-1Z_DATACO_JWDL_QC.las   ['AT20', 'AT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/204_20a-7_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RPCH', 'RSHAL', 'SP']
# WOS/204_10a-4_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RPCHM', 'RPCLM', 'RSHAL', 'SP']
# WOS/204_30-1_DATACO_JWDL_QC.las   ['DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_04-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_16-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_27-3Z_DATACO_JWDL_QC.las   ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT']
# WOS/204_19-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-8_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/214_27a-3_DATACO_JWDL_QC.las   ['AT20', 'AT60', 'ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_26a-2_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/209_04-1A_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/208_17-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/205_25-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_20-6A_DATACO_JWDL_QC.las   ['AT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/214_19-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEWP', 'SP']
# WOS/202_02-1_DATACO_JWDL_QC.las   ['CALI', 'DTC', 'GR', 'RDEP', 'RSHAL', 'SP']
# WOS/204_25-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_20-1_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MLL', 'NEUT', 'SN', 'SP']
# WOS/206_08-15_DATACO_JWDL_QC.las   ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/204_24a-2Z_DATACO_JWDL_QC.las   ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RSHAL']

# %%
basic_curve_set = ['GR','DENS','NEUT','DTC']
incomplete = {}
count=0
for filename, curve in file_curves.items():
    for mnem in basic_curve_set:
        if mnem not in curve:
            incomplete[filename] = curve
for filename, curves in incomplete.items():
    count+=1
    print(filename, ' - ', curves)
    
print('\nNumber of wells that do not have all GR, DENS, NEUT, DTC is:',count)
# Out:
# WOS/204_19-8_DATACO_JWDL_QC.las  -  ['CALI', 'DTC', 'GR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/202_18-1_DATACO_JWDL_QC.las  -  ['CALI', 'DTC', 'GR', 'ILD', 'ILM', 'RD', 'RDEP', 'RFOC', 'RMIC', 'RS']
# WOS/213_27-4Z_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS']
# WOS/217_15-1_DATACO_JWDL_QC.las  -  ['BDCM', 'CALCM', 'CALI', 'DENC', 'DENS', 'DPEM', 'DRHM', 'DTC', 'DTPM', 'DTSH3', 'DTSH5', 'DTSH6', 'DTSM', 'GRCM', 'NPLM', 'PEF', 'RACHM', 'RACLM', 'RPCHM', 'RPCLM']
# WOS/205_23-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'RDEP', 'RSHAL', 'SP']
# WOS/204_05a-1_DATACO_JWDL_QC.las  -  ['CALI_LWD', 'CALI_WL', 'DENC', 'DENS', 'DTC', 'DTS', 'GR_LWD', 'GR_WL', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RT_HRLT', 'RXO_HRLT']
# WOS/205_22-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_20-5_DATACO_JWDL_QC.las  -  ['DENC', 'DENS', 'GR', 'NEUT', 'RDEP', 'RMED', 'RMIC', 'RSHAL']
# WOS/206_08-10_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'PEF']
# WOS/202_02-1_DATACO_JWDL_QC.las  -  ['CALI', 'DTC', 'GR', 'RDEP', 'RSHAL', 'SP']
#
# Number of wells that do not have all GR, DENS, NEUT, DTC is: 10

# %%
las = lasio.read(path.join(DATAPATH, '204_23-1_DATACO_JWDL_QC.las'))
data = las.df()
# Out:
# Header section Parameter regexp=~P was not found.

# %%
plt.figure(figsize=(5,20))
plt.plot(data['GR'], data.index, '-r', linewidth=0.1, alpha = 1)
plt.ylim(4500,0)
plt.xlabel('Gamma Ray (API)')
plt.ylabel('Depth (m)')
plt.show()

# %%
med = data['GR'] - data['GR'].rolling(window=5, center=True).median()
indx = ~np.isnan(med)
plt.hist(med[indx],100)
plt.xlim([-20,20])
plt.show()

# %%
plt.figure(figsize=(5,20))
plt.plot(data['GR'], data.index,'-r', linewidth=0.1, alpha = 0.5)
plt.plot(data['GR'].rolling(window=5, center=True).median(), data.index, '-b', linewidth=0.3)
plt.ylim(4500,0)
plt.show()

# %%
top_depth, base_depth = 1000, 1100
plt.figure(figsize=(50,25))
plt.plot(data['GR'][top_depth:base_depth], '-b', alpha=0.5)
plt.plot(data['GR'][top_depth:base_depth].rolling(window=5, center=True).median(), '-r', linewidth=2)
plt.show()

# %%
plt.scatter(data['NEUT'], data['DENS'], c=data['GR'], cmap='summer_r', s=5, marker = 'x')
plt.xlabel('Neutron')
plt.ylabel('Bulk Density')
plt.title('Density - Neutron Cross Plot')
plt.colorbar()
plt.show()

# %%
basic_curve_set = ['GR','DENS','NEUT']
missing_curve=['DTC']
missDTC = {}

counter1=0
for filename, curve in file_curves.items():
    count1=0
    for mnem in basic_curve_set:
        if mnem in curve:
            count1+=1
        if 'DTC' not in curve and count1==3:
            missDTC[filename] = curve
            counter1+=1
for filename, curves in missDTC.items():
    print(filename, ' - ', curves)
    
print('\nNumber of wells that have GR, DENS, NEUT but not DTC is:',counter1)
# Out:
# WOS/213_27-4Z_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS']
# WOS/204_20-5_DATACO_JWDL_QC.las  -  ['DENC', 'DENS', 'GR', 'NEUT', 'RDEP', 'RMED', 'RMIC', 'RSHAL']
# WOS/206_08-10_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'GR', 'NEUT', 'PEF']
#
# Number of wells that have GR, DENS, NEUT but not DTC is: 3

# %%
basic_curve_set = ['GR','DENS','NEUT','DTC']
DTC = {}

counter2=0
for filename, curve in file_curves.items():
    count2=0
    for mnem in basic_curve_set:
        if mnem in curve:
            count2+=1
        if count2==4:
            DTC[filename] = curve
            counter2+=1
for filename, curves in DTC.items():
    print(filename, ' - ', curves)
    
print('\nNumber of wells that have GR, DENS, NEUT, DTC is:',counter2)
# Out:
# WOS/204_23-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/205_20-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_25c-1V_DATACO_JWDL_QC.las  -  ['AE20', 'AE60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RMED', 'RPCHM', 'RPCLM', 'RSHAL']
# WOS/214_26-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RAC', 'RDEP', 'RPC', 'RSHAL']
# WOS/204_25a-3_DATACO_JWDL_QC.las  -  ['AO10', 'AO20', 'AO30', 'AO60', 'AO90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_17-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RSHAL', 'RXO', 'SP']
# WOS/204_10-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'R25P', 'R55P', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_27a-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_16-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACM', 'RDEP', 'RMIC', 'RPCM', 'RSHAL']
# WOS/204_26-1A_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'IDPH', 'IMPH', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/204_22-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL']
# WOS/206_04-2_DATACO_JWDL_QC.las  -  ['A16H', 'A16L', 'A22H', 'A22L', 'A28H', 'A28L', 'A34H', 'A34L', 'A40H', 'A40L', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'GR_LWD', 'M2R1', 'M2R2', 'M2R3', 'M2R6', 'M2R9', 'M2RX', 'NEUT', 'P16H', 'P16L', 'P22H', 'P22L', 'P28H', 'P28L', 'P34H', 'P34L', 'P40H', 'P40L', 'PEF', 'RDEP', 'RES_BM', 'RES_BS', 'RES_RING', 'RMIC', 'RSHAL', 'SFR10C', 'SFR12C', 'SFR14C', 'SFR16C', 'SFR20C', 'SFR30C', 'SFR40C', 'SFR50C', 'SP']
# WOS/202_03-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_14-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'IDPH', 'IMPH', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SFLU']
# WOS/204_16-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RMLL', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50']
# WOS/205_27-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/214_27-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SP']
# WOS/208_21-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RMIC', 'RSHAL']
# WOS/205_01-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTSM', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS', 'RES_RING', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXO']
# WOS/202_09-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_10-5A_DATACO_JWDL_QC.las  -  ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/207_01-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_13-1_DATACO_JWDLC_QC.las  -  ['CALI', 'DENC', 'DENC_LWD', 'DENS', 'DENS_LWD', 'DTC', 'DTS', 'GR', 'NEUT', 'NEUT_LWD', 'PEF', 'RDEP', 'RDEP_LWD', 'RMED', 'RMED_LWD', 'RMIC', 'RMIC_LWD', 'RSHAL', 'RSHAL_LWD']
# WOS/205_23-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/205_26-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_01-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'SP']
# WOS/207_01-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/205_10-4_DATACO_JWDL_QC.las  -  ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/204_29a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_01-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_15-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'GR_LWD', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_12-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/204_19-7_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/208_11-1_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RXOZ', 'SP']
# WOS/214_28-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/206_08-4_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_23-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/207_02-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_21-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-11A_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'GR', 'NEUT', 'PEF', 'RXOZ', 'SP']
# WOS/206_12a-3_DATACO_JWDL_QC.las  -  ['AE10', 'AE20', 'AE30', 'AE60', 'AE90', 'BDCM', 'CALI', 'DENC', 'DENS', 'DTC', 'DTPM', 'DTS', 'GR', 'NEUT', 'NPLM', 'PEF', 'RACHM', 'RACLM', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RT_HRLT', 'RXO8', 'SP']
# WOS/207_01a-5_DATACO_JWDL_QC.las  -  ['AHT10', 'AHT20', 'AHT30', 'AHT60', 'AHT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'SP']
# WOS/206_05a-3_DATACO_JWDL_QC.las  -  ['DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXOZ', 'SP']
# WOS/206_01a-4Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'MLL', 'NEUT', 'PEF', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50', 'SP']
# WOS/204_24a-7_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS_1', 'DTS_2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/209_03-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/204_20-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_28-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'HDRA', 'NEUT', 'PEF', 'RDEP', 'RHOZ', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXOZ', 'SBD2', 'SCO2', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SPLF', 'TNPH']
# WOS/204_24-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_09-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'LL3', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-9_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SEMP']
# WOS/202_12-1_DATACO_JWDL_QC.las  -  ['ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/202_04-1_DATACO_JWDL_QC.las  -  ['AT60', 'ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/206_07-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/207_01a-4Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'SP']
# WOS/206_08-7A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/208_24-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'SP']
# WOS/207_01a-4_DATCO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-7_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/214_29-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/205_08-1_DATACO_JWDL_QC.las  -  ['AHO10', 'AHO20', 'AHO30', 'AHO60', 'AHO90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'SEDP', 'SEMP', 'SESP', 'SEWP', 'SEXP', 'SP']
# WOS/205_21-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'I5FR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'SFL', 'SP']
# WOS/205_21b-3_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS_1', 'DTS_2', 'GR', 'NEUT', 'PEF']
# WOS/204_24a-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/213_27-2_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT']
# WOS/217_15-1Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RT_HRLT', 'RXOZ']
# WOS/204_29-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SP']
# WOS/214_04-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SP']
# WOS/208_22-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_25a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/202_03-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/209_06-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_02-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_08-6A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/206_09-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/214_09-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RACL', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCH', 'RPCL', 'RXOZ', 'SP']
# WOS/204_25b-4_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-10Z_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'ATRT', 'ATRX', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/206_08-9Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'SEWR']
# WOS/206_11-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MLL', 'MSFL', 'NEUT', 'SFL', 'SP']
# WOS/205_12-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/204_24a-6_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/213_26-1_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT', 'SP']
# WOS/204_25b-6_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DT5', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'SEMP']
# WOS/205_17a-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_19-6_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-12A_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/202_08-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_24a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL']
# WOS/202_19-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SFLU', 'SP']
# WOS/208_23-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_21-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_14-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RACL', 'RACM', 'RDEP', 'RMIC', 'RPCH', 'RPCL', 'RPCM', 'RSHAL', 'SP']
# WOS/204_19-8Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_28-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/214_27-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/205_10-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/206_08-13Z_DATACO_JWDL_QC.las  -  ['AF10', 'AF20', 'AF30', 'AF60', 'AF90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/205_27a-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RSHAL', 'SP']
# WOS/208_27-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-14_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/213_28-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'GR_LWD', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RPCHM', 'RPCLM']
# WOS/205_14-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_22-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MSFL', 'NEUT', 'SFL']
# WOS/208_17-3_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RXO', 'SP']
# WOS/206_05-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_27-1Z_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DEPTH_M', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RMIC', 'RSHAL', 'RXOZ', 'SP']
# WOS/204_20-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_17b-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_30-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_10a-3_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_19-5_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_15-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'RD', 'RMLL', 'RS', 'SP']
# WOS/206_08-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_03-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/204_20-4_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_09-2_DATACO_JWDL_QC.las  -  ['A28H', 'CALI', 'DENC', 'DENS', 'DTC', 'DXDT', 'DYDT', 'GR', 'LLD', 'LLS', 'MSFL', 'NEUT', 'P28H', 'PEF', 'RT10', 'RT20', 'RT30', 'RT60', 'RT90', 'SP']
# WOS/214_30a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RPCHM', 'RPCLM', 'RXOZ', 'SP']
# WOS/204_14-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/204_24a-5_DATACO_JWDL_QC.las  -  ['AIT_10', 'AIT_20', 'AIT_30', 'AIT_60', 'AIT_90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/204_10-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SF10', 'SF12', 'SF14', 'SF16', 'SF20', 'SF30', 'SF40', 'SF50']
# WOS/204_18-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTX2', 'GR', 'NEUT', 'PEF', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SFR10', 'SFR12', 'SFR14', 'SFR16', 'SFR20', 'SFR30', 'SFR40', 'SFR50', 'SPLF']
# WOS/206_08-11Z_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'ATRT', 'ATRX', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/206_13-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/208_15-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/208_26-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/207_01-3_DATCO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SFLU', 'SP']
# WOS/206_01-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'M0R1', 'M0R2', 'M0R3', 'M0R6', 'M0R9', 'NEUT', 'PEF', 'RDEP', 'RIPD', 'RIPM', 'RMED', 'RSFL', 'RSHAL', 'SP']
# WOS/208_17-2_DATACO_JWDL_QC.las  -  ['AF30', 'AF90', 'AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT']
# WOS/206_08-3A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/208_19-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/209_12-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/206_08-5_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/209_09-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/202_03a-3_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL']
# WOS/206_13a-2A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'ILM', 'NEUT', 'PEF', 'RD', 'RS', 'SP']
# WOS/214_27a-4_DATACO_JWDL_QC.las  -  ['ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_07a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/214_30-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/204_25b-5_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF']
# WOS/208_15-2_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'ILD', 'ILM', 'LLD', 'LLS', 'NEUT', 'RMIC', 'SFLU', 'SP']
# WOS/214_17-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'MSFL', 'NEUT', 'PEF', 'R25A', 'R25P', 'R55A', 'R55P', 'SP']
# WOS/214_24-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEDP', 'SEMP', 'SESP', 'SEXP', 'SP']
# WOS/204_20-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_10-2B_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED']
# WOS/205_05a-1_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DT1', 'DT2', 'DTC', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_RING', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RT', 'RXOZ']
# WOS/204_24a-2Y_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP']
# WOS/204_19-4A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_16-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/213_27-4_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P28H', 'P34H', 'P40H', 'PEF', 'RES_BD', 'RES_BM', 'RES_BS', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'SP']
# WOS/204_19-3A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'RT', 'SP']
# WOS/204_23-2_DATACO_JWDL_QC.las  -  ['AHT20', 'AHT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RMED', 'RPCHM', 'RPCLM', 'RSHAL']
# WOS/206_08-9Y_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DT4P', 'DT4S', 'DTC', 'GR', 'NEUT', 'RDEP', 'RSHAL', 'SP']
# WOS/205_14-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'M2R1', 'M2R2', 'M2R3', 'M2R6', 'M2R9', 'M2RX', 'NEUT', 'PEF', 'RDC', 'RMLL', 'RSC', 'SP']
# WOS/204_20-1Z_DATACO_JWDL_QC.las  -  ['AT20', 'AT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/204_20a-7_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACH', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RPCH', 'RSHAL', 'SP']
# WOS/204_10a-4_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RACHM', 'RACLM', 'RDEP', 'RLA2', 'RLA4', 'RMED', 'RMIC', 'RPCHM', 'RPCLM', 'RSHAL', 'SP']
# WOS/204_30-1_DATACO_JWDL_QC.las  -  ['DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_04-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_16-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/213_27-3Z_DATACO_JWDL_QC.las  -  ['A16H', 'A22H', 'A28H', 'A34H', 'A40H', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'P16H', 'P22H', 'P34H', 'P40H', 'PEF', 'RDEP', 'RLA1', 'RLA2', 'RLA3', 'RLA4', 'RLA5', 'RMED', 'RSHAL', 'RXO_HRLT']
# WOS/204_19-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/206_08-8_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/214_27a-3_DATACO_JWDL_QC.las  -  ['AT20', 'AT60', 'ATR', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'LLD', 'LLS', 'NEUT', 'PEF', 'PSR', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/205_26a-2_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RMIC', 'RSHAL', 'SP']
# WOS/209_04-1A_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/208_17-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED']
# WOS/205_25-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMED', 'RSHAL', 'SP']
# WOS/204_20-6A_DATACO_JWDL_QC.las  -  ['AT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMED', 'RSHAL']
# WOS/214_19-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF', 'RDEP', 'RMIC', 'RSHAL', 'SEWP', 'SP']
# WOS/204_25-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'RDEP', 'RMIC', 'RSHAL', 'SP']
# WOS/205_20-1_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'ILD', 'LLD', 'LLS', 'MLL', 'NEUT', 'SN', 'SP']
# WOS/206_08-15_DATACO_JWDL_QC.las  -  ['AT10', 'AT20', 'AT30', 'AT60', 'AT90', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF']
# WOS/204_24a-2Z_DATACO_JWDL_QC.las  -  ['CALI', 'DENC', 'DENS', 'DTC', 'GR', 'NEUT', 'PEF', 'RDEP', 'RSHAL']
#
# Number of wells that have GR, DENS, NEUT, DTC is: 176

# %%
count3=0
for filename in DTC.items():
 
    las = lasio.read(filename[0])
    data = las.df()
    GR=data['GR'][~np.isnan(data['GR'])]
    GR=np.reshape(GR,(GR.shape[0],1))
    DENS=data['DENS'][~np.isnan(data['DENS'])]
    DENS=np.reshape(DENS,(DENS.shape[0],1))
    NEUT=data['NEUT'][~np.isnan(data['NEUT'])]
    NEUT=np.reshape(NEUT,(NEUT.shape[0],1))
    minlength=min(GR.shape[0],NEUT.shape[0],DENS.shape[0])
    dat=np.concatenate((GR[:minlength,:],DENS[:minlength,:],NEUT[:minlength,:]),axis=1)
    if count3==0:
        minl=dat.shape[0]
    if count3!=0:
        minl=min(dat.shape[0],minl)
        
    count3+=1
    
print('Minimum sequence length:',minl)
# Out:
# Header section Parameter regexp=~P was not found.
# /home/npp423/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Minimum sequence length: 743

# %%
count3=0
for filename in DTC.items():
 
    las = lasio.read(filename[0])
    data = las.df()
    GR=data['GR'][~np.isnan(data['GR'])]
    GR=np.reshape(GR,(GR.shape[0],1))
    DENS=data['DENS'][~np.isnan(data['DENS'])]
    DENS=np.reshape(DENS,(DENS.shape[0],1))
    NEUT=data['NEUT'][~np.isnan(data['NEUT'])]
    NEUT=np.reshape(NEUT,(NEUT.shape[0],1))
    minlength=min(GR.shape[0],NEUT.shape[0],DENS.shape[0])
    dat=np.concatenate((GR[:minlength,:],DENS[:minlength,:],NEUT[:minlength,:]),axis=1)
    DT=data['DTC'][~np.isnan(data['DTC'])]
    DT=np.reshape(DT,(DT.shape[0],1))
    if count3==0:
        traindat=dat[:minl-1,:]
        trainlbl=DT[:minl-1,:]
    if count3!=0:
        traindat=np.concatenate((traindat,dat[:minl-1,:]),axis=0)
        trainlbl=np.concatenate((trainlbl,DT[:minl-1,:]),axis=0)
    count3+=1
    
print(traindat.shape)
print(trainlbl.shape)
# Out:
# Header section Parameter regexp=~P was not found.
# /home/npp423/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# Header section Parameter regexp=~P was not found.
# (130592, 3)
# (130592, 1)

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(traindat[0:128000,:])
scaled_features = scaler.transform(traindat[0:128000,:])

scaler2 = preprocessing.StandardScaler().fit(trainlbl[0:128000,:])
scaled_labels = scaler2.transform(trainlbl[0:128000,:])
traindat=scaled_features.reshape(128000,3)
print(traindat.shape)
trainlbl=scaled_labels.reshape(128000)
print(trainlbl.shape)
# Out:
# (128000, 3)
# (128000,)

# %%
from keras.layers import Bidirectional, Concatenate, Permute, Dot, Input, LSTM, Multiply
from keras.layers import RepeatVector, Dense, Activation, Lambda
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.models import load_model, Model
import keras.backend as K
import numpy as np

import random
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
# %matplotlib inline
config = tf.ConfigProto( device_count = {'GPU': 1}) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def softmax(x, axis=1):
    """Softmax activation function.
    # Arguments
        x : Tensor.
        axis: Integer, axis along which the softmax normalization is applied.
    # Returns
        Tensor, output of softmax transformation.
    # Raises
        ValueError: In case `dim(x) == 1`.
    """
    ndim = K.ndim(x)
    if ndim == 2:
        return K.softmax(x)
    elif ndim > 2:
        e = K.exp(x - K.max(x, axis=axis, keepdims=True))
        s = K.sum(e, axis=axis, keepdims=True)
        return e / s
    else:
        raise ValueError('Cannot apply softmax to a tensor that is 1D')

# %%
import logging
import os
import subprocess

import pandas as pd
import numpy as np

from sklearn.manifold import TSNE

def setup_log(tag = 'VOC_TOPICS'):
    global logger
    # create logger
    logger = logging.getLogger(tag)
    # logger.handlers = []
    logger.propagate = False
    logger.setLevel(logging.DEBUG)
    # create console handler and set level to debug
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    # add formatter to ch
    ch.setFormatter(formatter)
    # add ch to logger
    # logger.handlers = []
    logger.addHandler(ch)

def setup_path(s3_prefix, data_dir):
    global local_data_dir, s3_input_prefix, s3_bucket
    s3_bucket = 's3://xxxxxx'
    local_data_dir = data_dir
    s3_input_prefix = s3_prefix

def exists_in_s3(key):
    ls = list_in_s3(key)
    if len(ls) > 0:
        if ls[0] == key[(key.rfind('/') + 1):]:
            return True
    return False

def list_in_s3(prefix):
    command = "aws s3 ls s3://{}/{}".format(s3_bucket, prefix)
    ls = subprocess.Popen(command.split(' '), stdout = subprocess.PIPE).stdout.read().split('\n')
    if len(ls) > 0:
        ls = [x[(x.rfind(' ') + 1):] for x in ls]
        return ls
    else:
        return []

def download_file(key):
    ## download
    command = 'aws s3 cp s3://{}/{} {}/'.format(s3_bucket, key, local_data_dir)
    status = subprocess.call(command.split(' '))
    if status != 0:
        logger.error('Error in downloading %s', key)
    else:
        logger.info('Downloaded file %s to local.', key)
        import re
    return

def plot_tsne(data, perplexity = 30, n_iter = 200):
    tsne = TSNE(perplexity = perplexity, n_components = 2, init = 'pca', n_iter = n_iter)
    low_dim_embs = tsne.fit_transform(data)
    plt.scatter(low_dim_embs[:, 0], low_dim_embs[:, 1])

# %%
import torch
from torch import nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

import matplotlib
# matplotlib.use('Agg')
# %matplotlib inline

import datetime as dt, itertools, pandas as pd, matplotlib.pyplot as plt, numpy as np



global logger

setup_log()

logger = logger


use_cuda = torch.cuda.is_available()
logger.info("Is CUDA available? %s.", use_cuda)
# Out:
# 2018-05-31 22:08:32,653 - VOC_TOPICS - INFO - Is CUDA available? True.

# %%
class encoder(nn.Module):
    def __init__(self, input_size, hidden_size, T, logger):
        # input size: number of underlying factors (81)
        # T: number of time steps (10)
        # hidden_size: dimension of the hidden state
        super(encoder, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.T = T

        self.logger = logger

        self.lstm_layer = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = 1)
        self.attn_linear = nn.Linear(in_features = 2 * hidden_size + T - 1, out_features = 1)

    def forward(self, input_data):
        # input_data: batch_size * T - 1 * input_size
        input_weighted = Variable(input_data.data.new(input_data.size(0), self.T - 1, self.input_size).zero_())
        input_encoded = Variable(input_data.data.new(input_data.size(0), self.T - 1, self.hidden_size).zero_())
        # hidden, cell: initial states with dimention hidden_size
        hidden = self.init_hidden(input_data) # 1 * batch_size * hidden_size
        cell = self.init_hidden(input_data)
        # hidden.requires_grad = False
        # cell.requires_grad = False
        for t in range(self.T - 1):
            # Eqn. 8: concatenate the hidden states with each predictor
            x = torch.cat((hidden.repeat(self.input_size, 1, 1).permute(1, 0, 2),
                           cell.repeat(self.input_size, 1, 1).permute(1, 0, 2),
                           input_data.permute(0, 2, 1)), dim = 2) # batch_size * input_size * (2*hidden_size + T - 1)
            # Eqn. 9: Get attention weights
            x = self.attn_linear(x.view(-1, self.hidden_size * 2 + self.T - 1)) # (batch_size * input_size) * 1
            attn_weights = F.softmax(x.view(-1, self.input_size),dim=-1) # batch_size * input_size, attn weights with values sum up to 1.
            # Eqn. 10: LSTM
            weighted_input = torch.mul(attn_weights, input_data[:, t, :]) # batch_size * input_size
            # Fix the warning about non-contiguous memory
            # see https://discuss.pytorch.org/t/dataparallel-issue-with-flatten-parameter/8282
            self.lstm_layer.flatten_parameters()
            _, lstm_states = self.lstm_layer(weighted_input.unsqueeze(0), (hidden, cell))
            hidden = lstm_states[0]
            cell = lstm_states[1]
            # Save output
            input_weighted[:, t, :] = weighted_input
            input_encoded[:, t, :] = hidden
        return input_weighted, input_encoded

    def init_hidden(self, x):
        # No matter whether CUDA is used, the returned variable will have the same type as x.
        return Variable(x.data.new(1, x.size(0), self.hidden_size).zero_()) # dimension 0 is the batch dimension

class decoder(nn.Module):
    def __init__(self, encoder_hidden_size, decoder_hidden_size, T, logger):
        super(decoder, self).__init__()

        self.T = T
        self.encoder_hidden_size = encoder_hidden_size
        self.decoder_hidden_size = decoder_hidden_size

        self.logger = logger

        self.attn_layer = nn.Sequential(nn.Linear(2 * decoder_hidden_size + encoder_hidden_size, encoder_hidden_size),
                                         nn.Tanh(), nn.Linear(encoder_hidden_size, 1))
        self.lstm_layer = nn.LSTM(input_size = 1, hidden_size = decoder_hidden_size)
        self.fc = nn.Linear(encoder_hidden_size + 1, 1)
        self.fc_final = nn.Linear(decoder_hidden_size + encoder_hidden_size, 1)

        self.fc.weight.data.normal_()

    def forward(self, input_encoded, y_history):
        # input_encoded: batch_size * T - 1 * encoder_hidden_size
        # y_history: batch_size * (T-1)
        # Initialize hidden and cell, 1 * batch_size * decoder_hidden_size
        hidden = self.init_hidden(input_encoded)
        cell = self.init_hidden(input_encoded)
        # hidden.requires_grad = False
        # cell.requires_grad = False
        for t in range(self.T - 1):
            # Eqn. 12-13: compute attention weights
            ## batch_size * T * (2*decoder_hidden_size + encoder_hidden_size)
            x = torch.cat((hidden.repeat(self.T - 1, 1, 1).permute(1, 0, 2),
                           cell.repeat(self.T - 1, 1, 1).permute(1, 0, 2), input_encoded), dim = 2)
            x = F.softmax(self.attn_layer(x.view(-1, 2 * self.decoder_hidden_size + self.encoder_hidden_size
                                                )).view(-1, self.T - 1),dim=-1) # batch_size * T - 1, row sum up to 1
            # Eqn. 14: compute context vector
            context = torch.bmm(x.unsqueeze(1), input_encoded)[:, 0, :] # batch_size * encoder_hidden_size
            if t < self.T - 1:
                # Eqn. 15
                y_tilde = self.fc(torch.cat((context, y_history[:, t].unsqueeze(1)), dim = 1)) # batch_size * 1
                # Eqn. 16: LSTM
                self.lstm_layer.flatten_parameters()
                _, lstm_output = self.lstm_layer(y_tilde.unsqueeze(0), (hidden, cell))
                hidden = lstm_output[0] # 1 * batch_size * decoder_hidden_size
                cell = lstm_output[1] # 1 * batch_size * decoder_hidden_size
        # Eqn. 22: final output
        y_pred = self.fc_final(torch.cat((hidden[0], context), dim = 1))
        # self.logger.info("hidden %s context %s y_pred: %s", hidden[0][0][:10], context[0][:10], y_pred[:10])
        return y_pred

    def init_hidden(self, x):
        return Variable(x.data.new(1, x.size(0), self.decoder_hidden_size).zero_())

# %%
# Train the model
class da_rnn:
    def __init__(self, data, logger, lbl, encoder_hidden_size = 64, decoder_hidden_size = 64, T = 10,
                 learning_rate = 0.01, batch_size = 128, parallel = True, debug = False):
        self.T = T
        
        self.logger = logger
        self.logger.info("Shape of data: %s", dat.shape)

        self.X = data
        self.y = lbl
        self.batch_size = batch_size

        self.encoder = encoder(input_size = self.X.shape[1], hidden_size = encoder_hidden_size, T = T,
                              logger = logger).cuda()
        self.decoder = decoder(encoder_hidden_size = encoder_hidden_size,
                               decoder_hidden_size = decoder_hidden_size,
                               T = T, logger = logger).cuda()

        if parallel:
            self.encoder = nn.DataParallel(self.encoder)
            self.decoder = nn.DataParallel(self.decoder)

        self.encoder_optimizer = optim.Adam(params = filter(lambda p: p.requires_grad, self.encoder.parameters()),
                                           lr = learning_rate)
        self.decoder_optimizer = optim.Adam(params = filter(lambda p: p.requires_grad, self.decoder.parameters()),
                                           lr = learning_rate)
        # self.learning_rate = learning_rate

        self.train_size = int(self.X.shape[0] * 0.8)
        
        self.logger.info("Training size: %d.", self.train_size)
        
    def train(self, n_epochs = 10):
        iter_per_epoch = int(np.ceil(self.train_size * 1. / self.batch_size))
        logger.info("Iterations per epoch: %3.3f ~ %d.", self.train_size * 1. / self.batch_size, iter_per_epoch)
        self.iter_losses = np.zeros(n_epochs * iter_per_epoch)
        self.epoch_losses = np.zeros(n_epochs)

        self.loss_func = nn.MSELoss()

        n_iter = 0

        learning_rate = 1.

        for i in range(n_epochs):
            perm_idx = np.random.permutation(self.train_size - self.T)
            j = 0
            while j < self.train_size:
                batch_idx = perm_idx[j:(j + self.batch_size)]
                X = np.zeros((len(batch_idx), self.T - 1, self.X.shape[1]))
                y_history = np.zeros((len(batch_idx), self.T - 1))
                y_target = self.y[batch_idx + self.T]

                for k in range(len(batch_idx)):
                    X[k, :, :] = self.X[batch_idx[k] : (batch_idx[k] + self.T - 1), :]
                    y_history[k, :] = self.y[batch_idx[k] : (batch_idx[k] + self.T - 1)]

                loss = self.train_iteration(X, y_history, y_target)
                self.iter_losses[int(i * iter_per_epoch + j / self.batch_size)] = loss
                if (j / self.batch_size) % 200 == 0:
                    self.logger.info("Epoch %d, Batch %d: loss = %3.3f.", i, j / self.batch_size, loss)
                j += self.batch_size
                n_iter += 1

                if n_iter % 10000 == 0 and n_iter > 0:
                    for param_group in self.encoder_optimizer.param_groups:
                        param_group['lr'] = param_group['lr'] * 0.9
                    for param_group in self.decoder_optimizer.param_groups:
                        param_group['lr'] = param_group['lr'] * 0.9
                '''
                if learning_rate > self.learning_rate:
                    for param_group in self.encoder_optimizer.param_groups:
                        param_group['lr'] = param_group['lr'] * .9
                    for param_group in self.decoder_optimizer.param_groups:
                        param_group['lr'] = param_group['lr'] * .9
                    learning_rate *= .9
                '''


            self.epoch_losses[i] = np.mean(self.iter_losses[range(i * iter_per_epoch, (i + 1) * iter_per_epoch)])
            if i % 10 == 0:
                self.logger.info("Epoch %d, loss: %3.3f.", i, self.epoch_losses[i])

            if i % 10 == 0:
                y_train_pred = self.predict(on_train = True)
                y_test_pred = self.predict(on_train = False)
                y_pred = np.concatenate((y_train_pred, y_test_pred))
                plt.figure()
                plt.plot(range(1, 1 + len(self.y)), self.y, label = "True")
                plt.plot(range(self.T , len(y_train_pred) + self.T), y_train_pred, label = 'Predicted - Train')
                plt.plot(range(self.T + len(y_train_pred) , len(self.y) + 1), y_test_pred, label = 'Predicted - Test')
                plt.legend(loc = 'upper left')
                plt.show()

    def train_iteration(self, X, y_history, y_target):
        self.encoder_optimizer.zero_grad()
        self.decoder_optimizer.zero_grad()

        input_weighted, input_encoded = self.encoder(Variable(torch.from_numpy(X).type(torch.FloatTensor).cuda()))
        y_pred = self.decoder(input_encoded, Variable(torch.from_numpy(y_history).type(torch.FloatTensor).cuda()))

        y_true = Variable(torch.from_numpy(y_target).type(torch.FloatTensor).cuda())
        loss = self.loss_func(y_pred, y_true)
        loss.backward()

        self.encoder_optimizer.step()
        self.decoder_optimizer.step()

        # if loss.data[0] < 10:
        #     self.logger.info("MSE: %s, loss: %s.", loss.data, (y_pred[:, 0] - y_true).pow(2).mean())

        return loss.data[0]

    def predict(self, on_train = False):
        if on_train:
            y_pred = np.zeros(self.train_size - self.T + 1)
        else:
            y_pred = np.zeros(self.X.shape[0] - self.train_size)

        i = 0
        while i < len(y_pred):
            batch_idx = np.array(range(len(y_pred)))[i : (i + self.batch_size)]
            X = np.zeros((len(batch_idx), self.T - 1, self.X.shape[1]))
            y_history = np.zeros((len(batch_idx), self.T - 1))
            for j in range(len(batch_idx)):
                if on_train:
                    X[j, :, :] = self.X[range(batch_idx[j], batch_idx[j] + self.T - 1), :]
                    y_history[j, :] = self.y[range(batch_idx[j],  batch_idx[j]+ self.T - 1)]
                else:
                    X[j, :, :] = self.X[range(batch_idx[j] + self.train_size - self.T, batch_idx[j] + self.train_size - 1), :]
                    y_history[j, :] = self.y[range(batch_idx[j] + self.train_size - self.T,  batch_idx[j]+ self.train_size - 1)]

            y_history = Variable(torch.from_numpy(y_history).type(torch.FloatTensor).cuda())
            _, input_encoded = self.encoder(Variable(torch.from_numpy(X).type(torch.FloatTensor).cuda()))
            y_pred[i:(i + self.batch_size)] = self.decoder(input_encoded, y_history).cpu().data.numpy()[:, 0]
            i += self.batch_size
        return y_pred

# %%
model = da_rnn(data=traindat, logger = logger, parallel = False,
              learning_rate = .001,lbl=trainlbl)

model.train(n_epochs = 500)

y_pred = model.predict()

plt.figure()
plt.semilogy(range(len(model.iter_losses)), model.iter_losses)
plt.show()

plt.figure()
plt.semilogy(range(len(model.epoch_losses)), model.epoch_losses)
plt.show()

plt.figure()
plt.plot(y_pred, label = 'Predicted')
plt.plot(model.y[model.train_size:], label = "True")
plt.legend(loc = 'upper left')
plt.show()
# Out:
# 2018-05-31 22:27:34,354 - VOC_TOPICS - INFO - Shape of data: (9092, 3)
# 2018-05-31 22:27:34,371 - VOC_TOPICS - INFO - Training size: 102400.
# 2018-05-31 22:27:34,372 - VOC_TOPICS - INFO - Iterations per epoch: 800.000 ~ 800.
# 2018-05-31 22:27:34,464 - VOC_TOPICS - INFO - Epoch 0, Batch 0: loss = 0.951.
# 2018-05-31 22:27:50,970 - VOC_TOPICS - INFO - Epoch 0, Batch 200: loss = 0.092.
# 2018-05-31 22:28:07,961 - VOC_TOPICS - INFO - Epoch 0, Batch 400: loss = 0.105.
# 2018-05-31 22:28:26,284 - VOC_TOPICS - INFO - Epoch 0, Batch 600: loss = 0.052.
# 2018-05-31 22:28:44,565 - VOC_TOPICS - INFO - Epoch 0, loss: 0.173.
# 2018-05-31 22:29:45,102 - VOC_TOPICS - INFO - Epoch 1, Batch 0: loss = 2.252.
# 2018-05-31 22:30:03,565 - VOC_TOPICS - INFO - Epoch 1, Batch 200: loss = 0.086.
# 2018-05-31 22:30:21,891 - VOC_TOPICS - INFO - Epoch 1, Batch 400: loss = 0.093.
# 2018-05-31 22:30:39,920 - VOC_TOPICS - INFO - Epoch 1, Batch 600: loss = 0.049.
# 2018-05-31 22:30:58,224 - VOC_TOPICS - INFO - Epoch 2, Batch 0: loss = 0.064.
# 2018-05-31 22:31:16,669 - VOC_TOPICS - INFO - Epoch 2, Batch 200: loss = 0.125.
# 2018-05-31 22:31:35,049 - VOC_TOPICS - INFO - Epoch 2, Batch 400: loss = 0.239.
# 2018-05-31 22:31:53,626 - VOC_TOPICS - INFO - Epoch 2, Batch 600: loss = 0.285.
# 2018-05-31 22:32:11,975 - VOC_TOPICS - INFO - Epoch 3, Batch 0: loss = 0.093.
# 2018-05-31 22:32:30,477 - VOC_TOPICS - INFO - Epoch 3, Batch 200: loss = 0.032.
# 2018-05-31 22:32:48,832 - VOC_TOPICS - INFO - Epoch 3, Batch 400: loss = 0.104.
# 2018-05-31 22:33:07,082 - VOC_TOPICS - INFO - Epoch 3, Batch 600: loss = 0.050.
# 2018-05-31 22:33:25,484 - VOC_TOPICS - INFO - Epoch 4, Batch 0: loss = 0.076.
# 2018-05-31 22:33:43,927 - VOC_TOPICS - INFO - Epoch 4, Batch 200: loss = 0.069.
# 2018-05-31 22:34:02,482 - VOC_TOPICS - INFO - Epoch 4, Batch 400: loss = 0.048.
# 2018-05-31 22:34:20,855 - VOC_TOPICS - INFO - Epoch 4, Batch 600: loss = 0.364.
# 2018-05-31 22:34:39,147 - VOC_TOPICS - INFO - Epoch 5, Batch 0: loss = 0.078.
# 2018-05-31 22:34:57,244 - VOC_TOPICS - INFO - Epoch 5, Batch 200: loss = 0.069.
# 2018-05-31 22:35:15,687 - VOC_TOPICS - INFO - Epoch 5, Batch 400: loss = 0.089.
# 2018-05-31 22:35:34,169 - VOC_TOPICS - INFO - Epoch 5, Batch 600: loss = 0.063.
# 2018-05-31 22:35:52,549 - VOC_TOPICS - INFO - Epoch 6, Batch 0: loss = 0.098.
# 2018-05-31 22:36:10,781 - VOC_TOPICS - INFO - Epoch 6, Batch 200: loss = 0.051.
# 2018-05-31 22:36:28,785 - VOC_TOPICS - INFO - Epoch 6, Batch 400: loss = 0.061.
# 2018-05-31 22:36:47,207 - VOC_TOPICS - INFO - Epoch 6, Batch 600: loss = 0.311.
# 2018-05-31 22:37:05,434 - VOC_TOPICS - INFO - Epoch 7, Batch 0: loss = 0.045.
# 2018-05-31 22:37:23,759 - VOC_TOPICS - INFO - Epoch 7, Batch 200: loss = 0.042.
# 2018-05-31 22:37:42,140 - VOC_TOPICS - INFO - Epoch 7, Batch 400: loss = 0.048.
# 2018-05-31 22:38:00,642 - VOC_TOPICS - INFO - Epoch 7, Batch 600: loss = 0.079.
# 2018-05-31 22:38:19,137 - VOC_TOPICS - INFO - Epoch 8, Batch 0: loss = 0.037.
# 2018-05-31 22:38:37,615 - VOC_TOPICS - INFO - Epoch 8, Batch 200: loss = 0.049.
# 2018-05-31 22:38:56,135 - VOC_TOPICS - INFO - Epoch 8, Batch 400: loss = 0.027.
# 2018-05-31 22:39:14,562 - VOC_TOPICS - INFO - Epoch 8, Batch 600: loss = 0.051.
# 2018-05-31 22:39:32,767 - VOC_TOPICS - INFO - Epoch 9, Batch 0: loss = 0.045.
# 2018-05-31 22:39:50,850 - VOC_TOPICS - INFO - Epoch 9, Batch 200: loss = 0.072.
# 2018-05-31 22:40:09,218 - VOC_TOPICS - INFO - Epoch 9, Batch 400: loss = 0.072.
# 2018-05-31 22:40:27,469 - VOC_TOPICS - INFO - Epoch 9, Batch 600: loss = 0.070.
# 2018-05-31 22:40:45,929 - VOC_TOPICS - INFO - Epoch 10, Batch 0: loss = 0.031.
# 2018-05-31 22:41:04,451 - VOC_TOPICS - INFO - Epoch 10, Batch 200: loss = 0.072.
# 2018-05-31 22:41:22,947 - VOC_TOPICS - INFO - Epoch 10, Batch 400: loss = 0.099.
# 2018-05-31 22:41:41,463 - VOC_TOPICS - INFO - Epoch 10, Batch 600: loss = 0.234.
# 2018-05-31 22:41:59,866 - VOC_TOPICS - INFO - Epoch 10, loss: 0.119.
# 2018-05-31 22:43:00,714 - VOC_TOPICS - INFO - Epoch 11, Batch 0: loss = 0.040.
# 2018-05-31 22:43:19,028 - VOC_TOPICS - INFO - Epoch 11, Batch 200: loss = 0.020.
# 2018-05-31 22:43:37,498 - VOC_TOPICS - INFO - Epoch 11, Batch 400: loss = 0.066.
# 2018-05-31 22:43:55,985 - VOC_TOPICS - INFO - Epoch 11, Batch 600: loss = 0.195.
# 2018-05-31 22:44:14,491 - VOC_TOPICS - INFO - Epoch 12, Batch 0: loss = 0.047.
# 2018-05-31 22:44:32,764 - VOC_TOPICS - INFO - Epoch 12, Batch 200: loss = 0.192.
# 2018-05-31 22:44:50,143 - VOC_TOPICS - INFO - Epoch 12, Batch 400: loss = 0.030.
# 2018-05-31 22:45:08,598 - VOC_TOPICS - INFO - Epoch 12, Batch 600: loss = 0.048.
# 2018-05-31 22:45:27,045 - VOC_TOPICS - INFO - Epoch 13, Batch 0: loss = 0.036.
# 2018-05-31 22:45:45,534 - VOC_TOPICS - INFO - Epoch 13, Batch 200: loss = 0.156.
# 2018-05-31 22:46:04,081 - VOC_TOPICS - INFO - Epoch 13, Batch 400: loss = 0.072.
# 2018-05-31 22:46:22,500 - VOC_TOPICS - INFO - Epoch 13, Batch 600: loss = 0.103.
# 2018-05-31 22:46:39,979 - VOC_TOPICS - INFO - Epoch 14, Batch 0: loss = 0.043.
# 2018-05-31 22:46:58,485 - VOC_TOPICS - INFO - Epoch 14, Batch 200: loss = 0.089.
# 2018-05-31 22:47:17,190 - VOC_TOPICS - INFO - Epoch 14, Batch 400: loss = 0.033.
# 2018-05-31 22:47:35,730 - VOC_TOPICS - INFO - Epoch 14, Batch 600: loss = 0.054.
# 2018-05-31 22:47:54,351 - VOC_TOPICS - INFO - Epoch 15, Batch 0: loss = 0.085.
# 2018-05-31 22:48:12,930 - VOC_TOPICS - INFO - Epoch 15, Batch 200: loss = 0.958.
# 2018-05-31 22:48:31,471 - VOC_TOPICS - INFO - Epoch 15, Batch 400: loss = 0.112.
# 2018-05-31 22:48:49,830 - VOC_TOPICS - INFO - Epoch 15, Batch 600: loss = 0.074.
# 2018-05-31 22:49:07,988 - VOC_TOPICS - INFO - Epoch 16, Batch 0: loss = 0.033.
# 2018-05-31 22:49:26,253 - VOC_TOPICS - INFO - Epoch 16, Batch 200: loss = 0.048.
# 2018-05-31 22:49:44,206 - VOC_TOPICS - INFO - Epoch 16, Batch 400: loss = 0.167.
# 2018-05-31 22:50:02,610 - VOC_TOPICS - INFO - Epoch 16, Batch 600: loss = 0.059.
